# %% [markdown]
# # Compound extremes in SMYLE

# %%
# general use packages
# %matplotlib inline
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import numpy as np

# packages for altering time to match up!
import sys
import cftime

# climpred packages
# import climpred
# from climpred import HindcastEnsemble
# from climpred.tutorial import load_dataset
# from climpred.stats import rm_poly

# SMYLE Utility functions
from SMYLEutils import io_utils as io
from SMYLEutils import calendar_utils as cal
from SMYLEutils import stat_utils as stat

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ## Select initialization

# %%
init = 11# 2, 5, 8, or 11

# %% [markdown]
# ## load data

# %%
sst_ext = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/TEMP.monthly.' + str(init) + '.regrid.extremes.0.9.final.nc')['extreme']
# ohc_ext = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/100m_OHC.monthly.' + str(init) + '.regrid.extremes.0.9.nc')['extreme']
o2_ext = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/O2.monthly.' + str(init) + '.regrid.extremes.0.1.update.log.nc')['extreme']
ph_ext = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/pH_3D.monthly.' + str(init) + '.regrid.extremes.0.9.final.nc')['extreme']

# %%
# biol. extremes
thold = '0.9'
# bio_high = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/photoC_tot_zint_100m.monthly.' + str(init) + '.regrid.extremes.0.9.nc')['extreme']
biomass_high = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.monthly.' + str(init) + '.regrid.extremes.0.9.update.log.nc')['extreme']
# chl_high = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totChl_zint_100m.monthly.' + str(init) + '.regrid.extremes.0.9.nc')[ 'extreme']
# zoo_high = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/zooC.monthly.' + str(init) + '.regrid.extremes.0.9.nc')['extreme']


thold = '0.1'
# bio_low = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/photoC_tot_zint_100m.monthly.' + str(init) + '.regrid.extremes.0.1.nc')['extreme']
biomass_low = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.monthly.' + str(init) + '.regrid.extremes.0.1.update.log.nc')['extreme']
# chl_low = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totChl_zint_100m.monthly.' + str(init) + '.regrid.extremes.0.1.nc')['extreme']
# zoo_low = xr.open_dataset('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/zooC.monthly.' + str(init) + '.regrid.extremes.0.1.nc')['extreme']

# %% [markdown]
# # let's save them out now

# %%
biomass_high_sst = (biomass_high.where(sst_ext == 1) > 0)
biomass_high_ph  = (biomass_high.where(ph_ext == 1) > 0)
biomass_high_o2  = (biomass_high.where(o2_ext  == 1) > 0)

# %%
biomass_low_sst = (biomass_low.where(sst_ext == 1) > 0)
biomass_low_ph  = (biomass_low.where(ph_ext == 1) > 0)
biomass_low_o2  = (biomass_low.where(o2_ext  == 1) > 0)

# %%
biomass_high_sst.to_netcdf('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.TEMP.monthly.' + str(init) + '.regrid.extremes.0.9.final.nc')
biomass_high_ph.to_netcdf('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.pH_3D.monthly.' + str(init) + '.regrid.extremes.0.9.final.nc')
biomass_high_o2.to_netcdf('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.O2.monthly.' + str(init) + '.regrid.extremes.0.9.final.nc')

# %%
biomass_low_sst.to_netcdf('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.TEMP.monthly.' + str(init) + '.regrid.extremes.0.1.final.nc')
biomass_low_ph.to_netcdf('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.pH_3D.monthly.' + str(init) + '.regrid.extremes.0.1.final.nc')
biomass_low_o2.to_netcdf('/glade/derecho/scratch/smogen/Chl_extremes/monthly/SMYLE/extremes/totC_zint_100m.O2.monthly.' + str(init) + '.regrid.extremes.0.1.final.nc')
